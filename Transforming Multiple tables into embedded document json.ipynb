# %% [markdown]
# ## In this notebook, we will transform multiple tables into embedded document in json format for importing into mongodb

# %%
import pandas as pd
from datetime import datetime
from langdetect import detect
import math
from tqdm.notebook import tqdm
import json

# %%
# import libraries and run a few checks
import sys
assert sys.version_info >= (3, 5)

import sklearn
assert sklearn.__version__ >= "0.20"

import numpy as np
import pandas as pd
import scipy.stats as stats
import os


import warnings 
warnings.filterwarnings('ignore')

# util to reduce memory usage
## From kernel https://www.kaggle.com/gemartin/load-data-reduce-memory-usage
def reduce_memory_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                else:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose:
        print(f'Memory usage decreased to {end_mem:.2f} Mb ({1-end_mem/start_mem:.2%} reduction)')
    return df

# %%
# importing cleaned and generated data
calendar_df = pd.read_csv('calendar_cleaned.csv',  encoding="utf-8")
listings_df = pd.read_csv('listings_cleaned.csv',  encoding="utf-8")
reviews_df = pd.read_csv('reviews_cleaned.csv',  encoding="utf-8")
customers_df = pd.read_csv('customers.csv',  encoding="utf-8")
transactions_df = pd.read_csv('transactions.csv',  encoding="utf-8")

# %%
#create host table based on our schema
host_df = listings_df[['host_id', 'host_name', 'host_url', 'host_since','host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
       'host_neighbourhood','host_has_profile_pic','host_identity_verified','host_verifications']].copy()

# %%
test_df = pd.DataFrame(listings_df.groupby(['host_id'])['id'].nunique())

# %%
test_df.sort_values(by=['id'], ascending = False)
# Out:
#             id
# host_id
# 201677068  195
# 39669202   102
# 52161947    81
# 26736483    71
# 187786849   65
# ...        ...
# 79482033     1
# 79459332     1
# 79244729     1
# 79171682     1
# 464700027    1
#
# [7639 rows x 1 columns]

# %%
test_df.loc[test_df['id'] == 1].count()/test_df.shape[0]
# Out:
# id    0.700223
# dtype: float64

# %%
test2_df = pd.DataFrame(listings_df.groupby(['id'])['host_id'].nunique())

# %%
test2_df.loc[test2_df['host_id'] != 1].count()
# Out:
# host_id    0
# dtype: int64

# %%
listings_df = listings_df[['id','listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
                'neighborhood_overview', 'picture_url', 'host_id','neighbourhood','neighbourhood_cleansed',
                'latitude', 'longitude', 'property_type','room_type', 'accommodates', 'bathrooms_text', 
                'bedrooms', 'beds', 'calendar_last_scraped', 'review_scores_rating', 'review_scores_accuracy',
                'review_scores_cleanliness', 'review_scores_checkin',
                'review_scores_communication', 'review_scores_location',
                'review_scores_value', 'instant_bookable']]

# %% [markdown]
# ### Queries
#
# Show the listings available for booking from X date for Y days. User can select optional filters (can just demonstrate three as example?):​
#
# 	Accommodates X people​
#
# 	Price within X range (total price for that period, referencing calendar table)​
#
# 	Review score rating greater than X​
#
# 	Property type​
#
# 	Etc.​
#
# Demonstrate join with host table:​
#
# 	Show the listings where the host is a superhost​
#
# 	Demonstrate join with amenities table:​
#
# 	e.g. Show the listings with WiFi​
#
# Demonstrate join with reviews table:​
#
# 	Show the reviews for listing X​
#
# 5. Average Check in/ average price past 12 months for certain listings​
#
# 6. Calculate total listings of certain host​
#
# 7. total revenue of a certain host for certain period (transaction join listing join host)​
#
# 8. find listings with at least one review (review score ratings is not null)

# %% [markdown]
# #### transforming calendar by dates, group by listing id, for embedded documents, merge to listings using listing id
# listing_id : "dates":[{"date" : "2022-06-20",
#                       "available": "t",
#                       "price": 890,
#                       "adjusted_price": 890,
#                       "minimum_nights": 1,
#                       "maximum_nights": 365,
#                       },
#                       ]

# %%
import re
def concatstring(list1, cols):
    numerics = ['minimum_nights', 
                'maximum_nights', 
                'host_id', 
                'review_id', 
                'customer_id', 
                'transaction_id', 
                'length_of_stay', 
                'cost_per_day', 
                'total_cost', 
                'number_of_guests', 
                'refund_percentage']
    
    string = "{"
    for i,item in enumerate(list1):
        
        if str(item) == 'nan':
            string = string + "\"" + cols[i] + "\" : " + "null" + ","
            
        else:
            
            if type(item) != 'str':
                item = str(item)
                
            if cols[i] in numerics:
                string = string + "\"" + cols[i] + "\" : " + item + ","
            elif item.startswith('$') or 'price' in cols[i]:
                string = string + "\"" + cols[i] + "\" : " + item.strip('$').replace(",","") + ","
            elif item.endswith('%') or 'rate' in cols[i]:
                string = string + "\"" + cols[i] + "\" : " + item.strip('%') + ","
            elif re.match(r'\d{4}-\d{2}-\d{2}', item):
            #    string = string + "\"" + cols[i] + "\" : " + "ISODate(\"" + item + "T00:00:00.000Z" + "\")," 
                string = string + "\"" + cols[i] + "\" : " + "\"" + item + "T00:00:00.000Z" + "\"," 
            elif item.endswith(']') and item.startswith('['):
                string = string + "\"" + cols[i] + "\" : " + item.replace("\'","\"") + ","
            else:
                string = string + "\"" + cols[i] + "\" : " + "\"" + item + "\","

    string = string + "}"
    
    return string

# %%
calendar_df = pd.read_csv('calendar_cleaned.csv',  encoding="utf-8")

# %%
cols = calendar_df.columns.tolist()
cols.remove('listing_id')
calendar_df['dates'] = calendar_df.apply(lambda x: concatstring([x.date, 
                                                                 x.available, 
                                                                 x.price, 
                                                                 x.adjusted_price, 
                                                                 x.minimum_nights, 
                                                                 x.maximum_nights],cols), axis = 1)

# %%
calendar_df = calendar_df.groupby(['listing_id'])['dates'].agg(lambda x: ",".join(str(v)[:-2] + "}" for v in x))

# %%
calendar_df = pd.DataFrame({'listing_id':calendar_df.index, 'dates':calendar_df.values})

# %%
calendar_df['dates'] = calendar_df['dates'].apply(lambda x: "[" + x + "]")

# %%
calendar_df.iloc[1]['dates']
# Out:
# '[{"date" : "2022-06-21","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-22","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-23","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-24","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-25","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-26","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-27","available" : "f","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-28","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-29","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-06-30","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-01","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-02","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-03","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-04","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-05","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-06","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-07","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-08","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-09","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-10","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-11","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-12","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-13","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-14","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-15","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-16","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-17","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-18","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-19","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date" : "2022-07-20","available" : "t","price" : 1342.0,"adjusted_price" : 1342.0,"minimum_nights" : 1.0,"maximum_nights" : 730.0},{"date"  ...

# %%
calendar_df.to_csv('calendar_df_transformed.csv', index = False, columns = calendar_df.columns.tolist())

# %% [markdown]
# ####  transforming host by host ids, merge to listings using host_id

# %%
cols = host_df.columns.tolist()
host_df['hosts'] = host_df.apply(lambda x: concatstring([x.host_id,
                                                        x.host_name,
                                                        x.host_url,
                                                        x.host_since,
                                                        x.host_location,
                                                        x.host_about,
                                                        x.host_response_time,
                                                        x.host_response_rate,
                                                        x.host_acceptance_rate,
                                                        x.host_is_superhost,
                                                        x.host_thumbnail_url,
                                                        x.host_picture_url,
                                                        x.host_neighbourhood,
                                                        x.host_has_profile_pic,
                                                        x.host_identity_verified,
                                                        x.host_verifications],cols), axis = 1)

# %%
host_df = host_df.drop_duplicates()

# %%
host_df = pd.DataFrame({'host_id':host_df['host_id'], 'hosts':host_df['hosts']})
host_df['hosts'] = host_df['hosts'].apply(lambda x: x[:-2] + "}")

# %%
host_df.iloc[2]['hosts']
# Out:
# '{"host_id" : 303573998,"host_name" : "Noodee","host_url" : "https://www.airbnb.com/users/show/303573998","host_since" : "2019-10-21","host_location" : "TH","host_about" : null,"host_response_time" : "a few days or more","host_response_rate" : 0.0,"host_acceptance_rate" : null,"host_is_superhost" : "f","host_thumbnail_url" : "https://a0.muscache.com/im/pictures/user/3ed3b465-3c37-4737-a4d0-b865ec8f31b4.jpg?aki_policy=profile_small","host_picture_url" : "https://a0.muscache.com/im/pictures/user/3ed3b465-3c37-4737-a4d0-b865ec8f31b4.jpg?aki_policy=profile_x_medium","host_neighbourhood" : null,"host_has_profile_pic" : "t","host_identity_verified" : "t","host_verifications" : ["email", "phone"]}'

# %%
host_df.to_csv('host_df_transformed.csv', index = False, columns = host_df.columns.tolist())

# %% [markdown]
# #### merge review and transaction and customer, then transform by reviewer ids, merge to listings using listing_id

# %%
transactions_df = pd.read_csv('transactions.csv',  encoding="utf-8")
reviews_df = pd.read_csv('reviews_cleaned.csv',  encoding="utf-8")
customers_df = pd.read_csv('customers.csv',  encoding="utf-8")

# %%
reviews_df = reviews_df.merge(transactions_df, left_on = ['id', 'listing_id'], right_on = ['review_id','listing_id'], how = 'left')

# %%
reviews_df = reviews_df.merge(customers_df,on = ['customer_id', 'customer_name'], how = 'right')

# %%
reviews_df.columns.tolist()
# Out:
# ['listing_id',
#  'id',
#  'date',
#  'reviewer_id',
#  'reviewer_name',
#  'comments',
#  'review_id',
#  'customer_id',
#  'review_date',
#  'customer_name',
#  'transaction_id',
#  'check_out_date',
#  'length_of_stay',
#  'check_in_date',
#  'transaction_date',
#  'cost_per_day',
#  'total_cost',
#  'number_of_guests',
#  'cancelled_transaction',
#  'refund_percentage',
#  'phone',
#  'email']

# %%
cols = reviews_df.columns.tolist()
cols.remove('listing_id')
cols.remove('id')
reviews_df['transactions'] = reviews_df.apply(lambda x: concatstring([x.date,
                                                                   x.reviewer_id,
                                                                   x.reviewer_name,
                                                                   x.comments,
                                                                   x.review_id,
                                                                   x.customer_id,
                                                                   x.review_date,
                                                                   x.customer_name,
                                                                   x.transaction_id,
                                                                   x.check_out_date,
                                                                   x.length_of_stay,
                                                                   x.check_in_date,
                                                                   x.transaction_date,
                                                                   x.cost_per_day,
                                                                   x.total_cost,
                                                                   x.number_of_guests,
                                                                   x.cancelled_transaction,
                                                                   x.refund_percentage,
                                                                   x.phone,
                                                                   x.email],cols), axis = 1)

# %%
reviews_df = reviews_df.groupby(['listing_id'])['transactions'].agg(lambda x: ",".join(str(v)[:-2] + "}" for v in x))
reviews_df = pd.DataFrame({'listing_id':reviews_df.index, 'transactions':reviews_df.values})
reviews_df['transactions'] = reviews_df['transactions'].apply(lambda x: "[" + x + "]")

# %%
reviews_df.iloc[3]['transactions']
# Out:
# '[{"date" : "2011-03-16","reviewer_id" : "371435","reviewer_name" : "Alan","comments" : "decent rooms friendly staff would book again","review_id" : null,"customer_id" : null,"review_date" : null,"customer_name" : null,"transaction_id" : null,"check_out_date" : null,"length_of_stay" : null,"check_in_date" : null,"transaction_date" : null,"cost_per_day" : null,"total_cost" : null,"number_of_guests" : null,"cancelled_transaction" : null,"refund_percentage" : null,"phone" : null,"email" : null},{"date" : "2011-06-13","reviewer_id" : "142645","reviewer_name" : "Christine","comments" : "I had a wonderful stay at sathorn terrace. Bangkok is such a big city and staying in a place that is centrally located is very key. Tor was such a wonderful host and such a big help in recommendations around the city. he went above and beyond to make our stay so comfortable and pleasant. thank you, tor!!\xa0\r<br/>","review_id" : null,"customer_id" : null,"review_date" : null,"customer_name" : null,"transaction_id" : null,"check_out_date" : null,"length_of_stay" : null,"check_in_date" : null,"transaction_date" : null,"cost_per_day" : null,"total_cost" : null,"number_of_guests" : null,"cancelled_transaction" : null,"refund_percentage" : null,"phone" : null,"email" : null},{"date" : "2011-06-26","reviewer_id" : "529456","reviewer_name" : "Catalina","comments" : "We have traveled to Thailand in june and stayed at Sathorn Terrace for a month. We can definitely say we found the perfect place for us. The apartment we rented looks nice and is pretty spacious and accommodating for two people. The neighborhood is a few stations away from one of the largest shopping centers in Thailand. We have the food store really close, as well as a couple of interesting restaurants nearby that are definitely worth trying. Mango Tree is just a few blocks away. We could easily find great food at very good prices, wether it\'s thai food, thai fruits or european dishes - we had no problem getting food and snacks every day and stay on a budget. The best pat is - you don\'t ever need to cook, just go out and have breakfast, lunch or dinner out in the city - it\'s affordable, accessible and tastes great. There are multiple connections to the rest of the city and you can get to the airport using the skytrain and express line alone.  Tor is a great guest and a great person. He helped us out with everything, showed us around the city and recommended a couple of places we should check out. Everybody at Sathorn Terrace is very friendly and nice. We are very happy with our choice and would like to stay again when we will visit Thailand in the future! Warmly recommended to everyone.","review_id" : 335142.0,"customer_id" : 529456.0,"review_date" : "2011-06-26","customer_name" : "Catalina","transaction_id" : 4708366.0,"check_out_date" : "2011-06-15","length_of_stay" : 10.0,"check_in_date" : "2011-06-05","transaction_date" : "2011-05-10","cost_per_day" : 1112.4,"total_cost" : 11124.0,"number_of_guests" : 1.0,"cancelled_transaction" : "f","refund_percentage" : 0.0,"phone" : "37860992.0","email" : "Catali3786@gmail.com"},{"date" : "2011-12-08","reviewer_id" : "955097","reviewer_name" : "Norman","comments" : "Tor is a great host and very accomodating. The staffs are efficient and taking care of me while Tor away to monastery.\r<br/>The location is excellent, especially for street foods lovers. Not too far from sky train station to travel around the city or the river.\r<br/>The cleanliness of the room is superb and the apartment is very secure.\r<br/>I will stay again in the future. I had a great stay and wished to stay longer!","review_id" : null,"customer_id" : null,"review_date" : null,"customer_name" : null,"transaction_id" : null,"check_out_date" : null,"length_of_stay" : null,"check_in_date" : null,"transaction_date" : null,"cost_per_day" : null,"total_cost" : null,"number_of_guests" : null,"cancelled_transaction" : null,"refund_percentage" : null,"phone" : null,"email" : null},{"date"  ...

# %%
reviews_df.to_csv('reviews_df_transformed.csv', index = False, columns = reviews_df.columns.tolist())

# %% [markdown]
# #### merge [calendar_df, host_df, reviews_df] to listings

# %%
calendar_df = pd.read_csv('calendar_df_transformed.csv',  encoding="utf-8")
reviews_df = pd.read_csv('reviews_df_transformed.csv',  encoding="utf-8")
host_df = pd.read_csv('host_df_transformed.csv',  encoding="utf-8")

# %%
listings_df = pd.read_csv('listings_cleaned.csv',  encoding="utf-8")
listings_df = listings_df[['id','listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
                'neighborhood_overview', 'picture_url', 'host_id','neighbourhood','neighbourhood_cleansed',
                'latitude', 'longitude', 'property_type','room_type', 'accommodates', 'bathrooms_text', 
                'bedrooms', 'beds', 'calendar_last_scraped', 'review_scores_rating', 'review_scores_accuracy',
                'review_scores_cleanliness', 'review_scores_checkin',
                'review_scores_communication', 'review_scores_location',
                'review_scores_value', 'instant_bookable']]
listings_df = listings_df.rename(columns = {"id":"listing_id"})

# %%
listings_df = listings_df.merge(calendar_df[['listing_id', 'dates']], on = 'listing_id', how = 'left' )

# %%
listings_df = listings_df.merge(host_df[['host_id', 'hosts']], on = 'host_id', how = 'left' )

# %%
listings_df = listings_df.merge(reviews_df[['listing_id', 'transactions']], on = 'listing_id', how = 'left' )

# %%
listings_df.shape[0]
# Out:
# 17074

# %%
listings_df.to_csv('transformed.csv', index = False, columns = listings_df.columns.tolist())

# %%
listings_df
# Out:
#                listing_id                                      listing_url  \
# 0      645048906856594097  https://www.airbnb.com/rooms/645048906856594097
# 1                15636062            https://www.airbnb.com/rooms/15636062
# 2                39544047            https://www.airbnb.com/rooms/39544047
# 3                34002624            https://www.airbnb.com/rooms/34002624
# 4                22678899            https://www.airbnb.com/rooms/22678899
# ...                   ...                                              ...
# 17069            22947580            https://www.airbnb.com/rooms/22947580
# 17070             5955949             https://www.airbnb.com/rooms/5955949
# 17071            32650300            https://www.airbnb.com/rooms/32650300
# 17072            46851152            https://www.airbnb.com/rooms/46851152
# 17073            46851039            https://www.airbnb.com/rooms/46851039
#
#             scrape_id last_scraped  \
# 0      20220620202126   2022-06-20
# 1      20220620202126   2022-06-20
# 2      20220620202126   2022-06-20
# 3      20220620202126   2022-06-20
# 4      20220620202126   2022-06-20
# ...               ...          ...
# 17069  20220620202126   2022-06-20
# 17070  20220620202126   2022-06-20
# 17071  20220620202126   2022-06-20
# 17072  20220620202126   2022-06-20
# 17073  20220620202126   2022-06-20
#
#                                                     name  \
# 0          Furnished 1 bedroom condo with beautiful view
# 1                               Akesin place ngamwongwan
# 2         IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                              Popular Condo Near IMPACT
# 4                                              บ้านเบนซ์
# ...                                                  ...
# 17069      Apartment T9 Muang Thong Thani by KhunNutt2B7
# 17070  Cozy Manor house with Lake view 520 square meters
# 17071                Studio Superior (Double Bed) Room 1
# 17072      Family Room Dmk Don mueang Airport 2 bedrooms
# 17073               Impact -Challenger Muang thong Thani
#
#                                              description  \
# 0      🏢Condo For rent: Lumpini Ville Nakhon In-River...
# 1      ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...
# 2                                                    NaN
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4      เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...
# ...                                                  ...
# 17069  ห้องพักส่วนตัวสวยหรูอยู่สบาย สะอาด ราคาประหยัด...
# 17070  Nice place for relax with wide lake at opposit...
# 17071  - Room size 25 sq.m. or 322 sq.ft.<br />- Quee...
# 17072  Apartment in Pak Kret, 2 bedrooms, 1 bathroom,...
# 17073  Apartment in Pak Kret, 1 bedroom, 1 bathroom, ...
#
#                                    neighborhood_overview  \
# 0                                Its in Lumpini building
# 1                                                    NaN
# 2      IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4                                                    NaN
# ...                                                  ...
# 17069  ที่พักอยู่ใกล้ห้างคอสโม แหล่งช้อปปิ้ง Sport Fa...
# 17070  There are many Thai restaurant near entrance o...
# 17071  Bangna Tower<br />40,000 square meters project...
# 17072                                                NaN
# 17073                                                NaN
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...    4663219
# 1      https://a0.muscache.com/pictures/f68098b9-3ff2...  100840975
# 2      https://a0.muscache.com/pictures/cc410e7d-922f...  303573998
# 3      https://a0.muscache.com/pictures/e4811699-0153...  256747704
# 4      https://a0.muscache.com/pictures/02e4ae53-dbe6...  167136634
# ...                                                  ...        ...
# 17069  https://a0.muscache.com/pictures/2cbf3a10-76e8...  169985358
# 17070  https://a0.muscache.com/pictures/93a7608f-f35c...   20002101
# 17071  https://a0.muscache.com/pictures/9a88370c-111c...  245251233
# 17072  https://a0.muscache.com/pictures/prohost-api/H...  201741826
# 17073  https://a0.muscache.com/pictures/prohost-api/H...  201741826
#
#                                            neighbourhood  ...  \
# 0      Tambon Talat Kwan, Chang Wat Nonthaburi, Thailand  ...
# 1                                                    NaN  ...
# 2                    Tambon Ban Mai, จ.นนทบุรี, Thailand  ...
# 3            ตำบล บางพูด, Chang Wat Nonthaburi, Thailand  ...
# 4                                                    NaN  ...
# ...                                                  ...  ...
# 17069     Tambon Ban Mai, Chang Wat Nonthaburi, Thailand  ...
# 17070  Tambon Bang Nam Chut, Chang Wat Samut Sakhon, ...  ...
# 17071                    บางแก้ว, Samut Prakan, Thailand  ...
# 17072                                                NaN  ...
# 17073                                                NaN  ...
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        5.0                        5.0
# 3                        5.0                        5.0
# 4                        NaN                        NaN
# ...                      ...                        ...
# 17069                    NaN                        NaN
# 17070                    NaN                        NaN
# 17071                    NaN                        NaN
# 17072                    NaN                        NaN
# 17073                    NaN                        NaN
#
#        review_scores_checkin review_scores_communication  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        5.0                         5.0
# 3                        5.0                         4.0
# 4                        NaN                         NaN
# ...                      ...                         ...
# 17069                    NaN                         NaN
# 17070                    NaN                         NaN
# 17071                    NaN                         NaN
# 17072                    NaN                         NaN
# 17073                    NaN                         NaN
#
#       review_scores_location  review_scores_value instant_bookable  \
# 0                        NaN                  NaN                t
# 1                        NaN                  NaN                f
# 2                       4.67                 4.67                t
# 3                       4.50                 4.00                t
# 4                        NaN                  NaN                t
# ...                      ...                  ...              ...
# 17069                    NaN                  NaN                t
# 17070                    NaN                  NaN                f
# 17071                    NaN                  NaN                t
# 17072                    NaN                  NaN                t
# 17073                    NaN                  NaN                t
#
#                                                    dates  \
# 0      [{"date" : "2022-06-20","available" : "t","pri...
# 1      [{"date" : "2022-06-20","available" : "t","pri...
# 2      [{"date" : "2022-06-20","available" : "t","pri...
# 3      [{"date" : "2022-06-20","available" : "t","pri...
# 4      [{"date" : "2022-06-20","available" : "t","pri...
# ...                                                  ...
# 17069  [{"date" : "2022-06-20","available" : "t","pri...
# 17070  [{"date" : "2022-06-20","available" : "t","pri...
# 17071  [{"date" : "2022-06-20","available" : "t","pri...
# 17072  [{"date" : "2022-06-20","available" : "t","pri...
# 17073  [{"date" : "2022-06-20","available" : "t","pri...
#
#                                                    hosts  \
# 0      {"host_id" : 4663219,"host_name" : "Fawad","ho...
# 1      {"host_id" : 100840975,"host_name" : "Supika",...
# 2      {"host_id" : 303573998,"host_name" : "Noodee",...
# 3      {"host_id" : 256747704,"host_name" : "Krit","h...
# 4      {"host_id" : 167136634,"host_name" : "เบนซ์","...
# ...                                                  ...
# 17069  {"host_id" : 169985358,"host_name" : "Nath","h...
# 17070  {"host_id" : 20002101,"host_name" : "Nutchuda"...
# 17071  {"host_id" : 245251233,"host_name" : "Bangna P...
# 17072  {"host_id" : 201741826,"host_name" : "Your.Ren...
# 17073  {"host_id" : 201741826,"host_name" : "Your.Ren...
#
#                                             transactions
# 0                                                    NaN
# 1                                                    NaN
# 2      [{"date" : "2019-11-15","reviewer_id" : "27394...
# 3      [{"date" : "2019-06-01","reviewer_id" : "25693...
# 4                                                    NaN
# ...                                                  ...
# 17069                                                NaN
# 17070                                                NaN
# 17071                                                NaN
# 17072                                                NaN
# 17073                                                NaN
#
# [17074 rows x 31 columns]

# %%
listings_df2 = listings_df.fillna("")

# %% [markdown]
# ### Change to json then compass import mongodb

# %%
listings_df = pd.read_csv('transformed.csv',  encoding="utf-8")

# %%
listings_df2 = listings_df.fillna("")
listings_df2
# Out:
#                listing_id                                      listing_url  \
# 0      645048906856594097  https://www.airbnb.com/rooms/645048906856594097
# 1                15636062            https://www.airbnb.com/rooms/15636062
# 2                39544047            https://www.airbnb.com/rooms/39544047
# 3                34002624            https://www.airbnb.com/rooms/34002624
# 4                22678899            https://www.airbnb.com/rooms/22678899
# ...                   ...                                              ...
# 17069            22947580            https://www.airbnb.com/rooms/22947580
# 17070             5955949             https://www.airbnb.com/rooms/5955949
# 17071            32650300            https://www.airbnb.com/rooms/32650300
# 17072            46851152            https://www.airbnb.com/rooms/46851152
# 17073            46851039            https://www.airbnb.com/rooms/46851039
#
#             scrape_id last_scraped  \
# 0      20220620202126   2022-06-20
# 1      20220620202126   2022-06-20
# 2      20220620202126   2022-06-20
# 3      20220620202126   2022-06-20
# 4      20220620202126   2022-06-20
# ...               ...          ...
# 17069  20220620202126   2022-06-20
# 17070  20220620202126   2022-06-20
# 17071  20220620202126   2022-06-20
# 17072  20220620202126   2022-06-20
# 17073  20220620202126   2022-06-20
#
#                                                     name  \
# 0          Furnished 1 bedroom condo with beautiful view
# 1                               Akesin place ngamwongwan
# 2         IMPACT Thunder Dome Muangthong ND condo ( C1 )
# 3                              Popular Condo Near IMPACT
# 4                                              บ้านเบนซ์
# ...                                                  ...
# 17069      Apartment T9 Muang Thong Thani by KhunNutt2B7
# 17070  Cozy Manor house with Lake view 520 square meters
# 17071                Studio Superior (Double Bed) Room 1
# 17072      Family Room Dmk Don mueang Airport 2 bedrooms
# 17073               Impact -Challenger Muang thong Thani
#
#                                              description  \
# 0      🏢Condo For rent: Lumpini Ville Nakhon In-River...
# 1      ที่ของฉันใกล้กับร้านอาหารและของกิน และ ขนส่งสา...
# 2
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4      เป็นหมู่บ้านขนาดใหญ่มีหลายเฟส บ้านเป็นทาวน์โฮม...
# ...                                                  ...
# 17069  ห้องพักส่วนตัวสวยหรูอยู่สบาย สะอาด ราคาประหยัด...
# 17070  Nice place for relax with wide lake at opposit...
# 17071  - Room size 25 sq.m. or 322 sq.ft.<br />- Quee...
# 17072  Apartment in Pak Kret, 2 bedrooms, 1 bathroom,...
# 17073  Apartment in Pak Kret, 1 bedroom, 1 bathroom, ...
#
#                                    neighborhood_overview  \
# 0                                Its in Lumpini building
# 1
# 2      IMPACT ศูนย์แสดงสินค้า  550 m<br />IMPACT Chal...
# 3      คอนโดเมืองทองอยู่ในบริเวณเดียวกับศูนย์แสดงสินค...
# 4
# ...                                                  ...
# 17069  ที่พักอยู่ใกล้ห้างคอสโม แหล่งช้อปปิ้ง Sport Fa...
# 17070  There are many Thai restaurant near entrance o...
# 17071  Bangna Tower<br />40,000 square meters project...
# 17072
# 17073
#
#                                              picture_url    host_id  \
# 0      https://a0.muscache.com/pictures/miso/Hosting-...    4663219
# 1      https://a0.muscache.com/pictures/f68098b9-3ff2...  100840975
# 2      https://a0.muscache.com/pictures/cc410e7d-922f...  303573998
# 3      https://a0.muscache.com/pictures/e4811699-0153...  256747704
# 4      https://a0.muscache.com/pictures/02e4ae53-dbe6...  167136634
# ...                                                  ...        ...
# 17069  https://a0.muscache.com/pictures/2cbf3a10-76e8...  169985358
# 17070  https://a0.muscache.com/pictures/93a7608f-f35c...   20002101
# 17071  https://a0.muscache.com/pictures/9a88370c-111c...  245251233
# 17072  https://a0.muscache.com/pictures/prohost-api/H...  201741826
# 17073  https://a0.muscache.com/pictures/prohost-api/H...  201741826
#
#                                            neighbourhood  ...  \
# 0      Tambon Talat Kwan, Chang Wat Nonthaburi, Thailand  ...
# 1                                                         ...
# 2                    Tambon Ban Mai, จ.นนทบุรี, Thailand  ...
# 3            ตำบล บางพูด, Chang Wat Nonthaburi, Thailand  ...
# 4                                                         ...
# ...                                                  ...  ...
# 17069     Tambon Ban Mai, Chang Wat Nonthaburi, Thailand  ...
# 17070  Tambon Bang Nam Chut, Chang Wat Samut Sakhon, ...  ...
# 17071                    บางแก้ว, Samut Prakan, Thailand  ...
# 17072                                                     ...
# 17073                                                     ...
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0
# 1
# 2                        5.0                        5.0
# 3                        5.0                        5.0
# 4
# ...                      ...                        ...
# 17069
# 17070
# 17071
# 17072
# 17073
#
#        review_scores_checkin review_scores_communication  \
# 0
# 1
# 2                        5.0                         5.0
# 3                        5.0                         4.0
# 4
# ...                      ...                         ...
# 17069
# 17070
# 17071
# 17072
# 17073
#
#       review_scores_location  review_scores_value instant_bookable  \
# 0                                                                t
# 1                                                                f
# 2                       4.67                 4.67                t
# 3                        4.5                  4.0                t
# 4                                                                t
# ...                      ...                  ...              ...
# 17069                                                            t
# 17070                                                            f
# 17071                                                            t
# 17072                                                            t
# 17073                                                            t
#
#                                                    dates  \
# 0      [{"date" : "2022-06-20","available" : "t","pri...
# 1      [{"date" : "2022-06-20","available" : "t","pri...
# 2      [{"date" : "2022-06-20","available" : "t","pri...
# 3      [{"date" : "2022-06-20","available" : "t","pri...
# 4      [{"date" : "2022-06-20","available" : "t","pri...
# ...                                                  ...
# 17069  [{"date" : "2022-06-20","available" : "t","pri...
# 17070  [{"date" : "2022-06-20","available" : "t","pri...
# 17071  [{"date" : "2022-06-20","available" : "t","pri...
# 17072  [{"date" : "2022-06-20","available" : "t","pri...
# 17073  [{"date" : "2022-06-20","available" : "t","pri...
#
#                                                    hosts  \
# 0      {"host_id" : 4663219,"host_name" : "Fawad","ho...
# 1      {"host_id" : 100840975,"host_name" : "Supika",...
# 2      {"host_id" : 303573998,"host_name" : "Noodee",...
# 3      {"host_id" : 256747704,"host_name" : "Krit","h...
# 4      {"host_id" : 167136634,"host_name" : "เบนซ์","...
# ...                                                  ...
# 17069  {"host_id" : 169985358,"host_name" : "Nath","h...
# 17070  {"host_id" : 20002101,"host_name" : "Nutchuda"...
# 17071  {"host_id" : 245251233,"host_name" : "Bangna P...
# 17072  {"host_id" : 201741826,"host_name" : "Your.Ren...
# 17073  {"host_id" : 201741826,"host_name" : "Your.Ren...
#
#                                             transactions
# 0
# 1
# 2      [{"date" : "2019-11-15","reviewer_id" : "27394...
# 3      [{"date" : "2019-06-01","reviewer_id" : "25693...
# 4
# ...                                                  ...
# 17069
# 17070
# 17071
# 17072
# 17073
#
# [17074 rows x 31 columns]

# %%
def csv_to_json(csvf, jsonFilePath):
    jsonArray = []
    for index, row in csvf.iterrows():
        datadict = {}
        for col in csvf.columns.tolist():
            if col not in ['dates','hosts','transactions']:
                datadict[col] = row[col] 
            else:
                try:
                    datadict[col] = json.loads(row[col])
                except:
                    pass
        #print(json.dumps(datadict, indent=2, sort_keys=True))
        jsonArray.append(datadict)

    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
            jsonString = json.dumps(jsonArray, indent=4)
            jsonf.write(jsonString)

# %%
csv_to_json(listings_df2, 'transformed.json')

# %% [markdown]
# #### check

# %%
f = open('transformed.json')
Lines = f.readlines()

# %%
for i in range(0,10000):
    print(Lines[i])
# Out:
# [
#
#     {
#
#         "listing_id": 645048906856594097,
#
#         "listing_url": "https://www.airbnb.com/rooms/645048906856594097",
#
#         "scrape_id": 20220620202126,
#
#         "last_scraped": "2022-06-20T00:00:00.000Z",
#
#         "name": "Furnished 1 bedroom condo with beautiful view",
#
#         "description": "\ud83c\udfe2Condo For rent: Lumpini Ville Nakhon In-Riverview Condo \ud83c\udfe2<br /><br /> \ud83d\ude98 Only 1.3 km. from the Purple Line  \ud83d\ude84 Yaek Tiwanon Station, near Lotus and Makro, Nakhon In and BigC Tiwanon<br /><br /><b>The space</b><br />32 sqm<br /><br /><b>Guest access</b><br />You will get the entire condo access alont with elevator card",
#
#         "neighborhood_overview": "Its in Lumpini building",
#
#         "picture_url": "https://a0.muscache.com/pictures/miso/Hosting-645048906856594097/original/c235b616-353f-486c-84ce-2fec5048587d.jpeg",
#
#         "host_id": 4663219,
#
#         "neighbourhood": "Tambon Talat Kwan, Chang Wat Nonthaburi, Thailand",
#
#         "neighbourhood_cleansed": "Bang Sue",
#
#         "latitude": 13.843799037843002,
#
#         "longitude": 100.51220275461674,
#
#         "property_type": "Entire condo",
#
#         "room_type": "Entire home/apt",
#
#         "accommodates": 2,
#
#         "bathrooms_text": "1 bath",
#
#         "bedrooms": 1.0,
#
#         "beds": 1.0,
#
#         "calendar_last_scraped": "2022-06-20T00:00:00.000Z",
#
#         "review_scores_rating": "",
#
#         "review_scores_accuracy": "",
#
#         "review_scores_cleanliness": "",
#
#         "review_scores_checkin": "",
#
#         "review_scores_communication": "",
#
#         "review_scores_location": "",
#
#         "review_scores_value": "",
#
#         "instant_bookable": "t",
#
#         "dates": [
#
#             {
#
#                 "date": "2022-06-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-06-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-07-31T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-08-31T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-09-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-10-31T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-11-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-12-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-12-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-12-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-12-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 890.0,
#
#                 "adjusted_price": 890.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 365.0
#
#             },
#
#             {
#
#                 "date": "2022-12-05T00:00:00.000Z",
#
# ...
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-08-31T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-13T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-14T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-15T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-16T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-17T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-18T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-19T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-20T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-21T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-22T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-23T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-24T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-25T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-26T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-27T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-28T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-29T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-09-30T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-01T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-02T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-03T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-04T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-05T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-06T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-07T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-08T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-09T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-10T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-11T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
#
#                 "minimum_nights": 1.0,
#
#                 "maximum_nights": 1125.0
#
#             },
#
#             {
#
#                 "date": "2022-10-12T00:00:00.000Z",
#
#                 "available": "t",
#
#                 "price": 650.0,
#
#                 "adjusted_price": 650.0,
